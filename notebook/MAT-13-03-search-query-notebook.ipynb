# %%
import os
import shutil
import sys
from pathlib import Path

# Get project base directory (one level up from current working directory)
base_dir = Path.cwd().parent

base_application_dir = base_dir / "base_application"

# Convert to absolute string path
base_application_dir = str(base_application_dir.resolve())

# Add to Python path if not already present
if base_application_dir not in sys.path:
    sys.path.append(base_application_dir)

print("base_application added to PATH:")
print(base_application_dir)
# Out:
# base_application added to PATH:
# /home/flaniganp/Documents/my-python-buddy/base_application

# %%
from llama_cpp import Llama
from views_chat_utilities import get_cleaned_summary_response

# %%
# Load local fine-tuned model (GGUF) once at startup
model_name = "llama-2-7b-143k-codeAlpaca-q4_K_M-2025-10-29_1424.gguf"
llm = Llama(
    model_path=os.path.join(base_dir, "models", model_name),
    n_ctx=4096,  # expand to match the model’s training context
    n_gpu_layers=-1,  # keep all layers on GPU (auto-fit)
    verbose=False,  # disables most llama.cpp logs
)

# %%
# !django-admin startproject temp_project

# %%
import os
import getpass
import django
from django.conf import settings

# Set Django settings module
os.environ["DJANGO_SETTINGS_MODULE"] = "temp_project.temp_project.settings"

# Initialize Django
django.setup()

# Prompt user securely for Brave API key
BRAVE_API_KEY = getpass.getpass("Enter your Brave API key: ")

# Store it as an environment variable
os.environ["BRAVE_API_KEY"] = BRAVE_API_KEY

# Update Django settings dynamically
setattr(settings, "BRAVE_API_KEY", BRAVE_API_KEY)

# Confirm it’s now available
print("Brave API Key loaded successfully.")
# Out:
# Enter your Brave API key:  ········
# Brave API Key loaded successfully.

# %%
RELEVANT_SECURITY_DOMAINS = {
    "boost": [
        # Manually found good sources
        "arjancodes.com",
        # Core analyzers and secure-coding authorities
        "bandit.readthedocs.io",
        "semgrep.dev",
        "mypy.readthedocs.io",
        "docs.python.org",
        "owasp.org",
        # Reliable security blogs / research
        "snyk.io",
        "securitylab.github.com",
    ],
    "discard": ["reddit.com", "stackoverflow.com", "github.com", "gitlab.com", "quora.com", "geeksforgeeks.org"],
}
# Update Django settings dynamically
setattr(settings, "RELEVANT_SECURITY_DOMAINS", RELEVANT_SECURITY_DOMAINS)

# %%
questions = [
    "What is a secure alternative to the python pickle module?",
    "What are the security implications for the subprocess module?",
    "How should I mitigate 'subprocess call with shell=True identified'?",
    "What is a secure hashing algorithm to use instead of md5?",
    "What are common hardcoded secret patterns detected by Dodgy in Python?",
]

# %%
for i, user_question in enumerate(questions, start=1):
    cleaned_response, prompt_tokens, max_new_tokens = get_cleaned_summary_response(llm, user_question)
    print(f"\nQuestion {i}: {user_question}")
    print(f"Cleaned Response: {cleaned_response}")
    print(f"\n\nPrompt Tokens: {prompt_tokens}")
    print(f"Max New Tokens: {max_new_tokens}")
    print("-" * 88)
# Out:
# Question 1: What is a secure alternative to the python pickle module?
# Cleaned Response: A secure alternative to the Python pickle module is JSON.
#
# It provides a safer serialization method that protects against security risks and unsafe behaviors, such as insecure deserialiation of data from untrusted sources or automated scanning for mistakes early on before they become critical issues later downstream within an application's codebase HIGH TRUST .
#
# Source(s):
#   1.  Python Pickle Risks and Safer Serialization Alternatives | ArjanCodes;  (https://www.arjancodes.com/blog/python-pickle-module-security-risks-and-safer-alternatives/)
#   2.  pickle — Python object serialization;  (https://docs.python.org/3/library/pickle.html)
#   3.  larch-pickle - Python Package Health Analysis | Snyk;  (https://snyk.io/advisor/python/larch-pickle)
#   4.  Insecure Deserialization in Python | Semgrep;  (https://semgrep.dev/docs/learn/vulnerabilities/insecure-deserialization/python)
#   5.  3.12 cPickle -- Alternate implementation of pickle;  (https://docs.python.org/2.0/lib/module-cPickle.html)
#
#
# Prompt Tokens: 78
# Max New Tokens: 360
# ----------------------------------------------------------------------------------------
#
# Question 2: What are the security implications for the subprocess module?
# Cleaned Response: The subprocess module in Python provides a way to execute system commands and shell scripts.
#
# However, it is important for developers not only understand the security implications of using this functionality but also take steps towards preventing command injection vulnerabilities when user-controlled inputs are involved.
#
# Source(s):
#   1.  subprocess — Subprocess management;  (https://docs.python.org/3/library/subprocess.html)
#   2.  Command injection in Python: examples and prevention | Snyk;  (https://snyk.io/blog/command-injection-python-prevention-examples/)
#   3.  17.1. subprocess — Subprocess management — Python v2.7.3 documentation;  (https://docs.python.org/release/2.7.3/library/subprocess.html)
#   4.  Command Injection in Python | Semgrep;  (https://semgrep.dev/docs/cheat-sheets/python-command-injection)
#   5.  subprocess.run - Python Package Health Analysis | Snyk;  (https://snyk.io/advisor/python/subprocess-run)
#
#
# Prompt Tokens: 121
# Max New Tokens: 360
# ----------------------------------------------------------------------------------------
#
# Question 3: How should I mitigate 'subprocess call with shell=True identified'?
# Cleaned Response: The issue of subprocess call with shell=True identified is a security risk due to the potential for command injection.
#
# Using this parameter without proper sanitization can lead to execution or manipulation by an attacker, potentially allowing them access and control over your system's resources (either directly through Python code that uses these functions).
#
# To mitigate such risks: 1) Use a safer alternative like `subprocess.check_call` without the shell parameter for executing commands safely; or if you need to use it, ensure proper sanitization of user input by using methods provided in subclasses (either from Python's built-in functions and classes that handle this automatically). 2) If your application is not able to avoid these risks due to specific requirements: a.
#
# Use the `subprocess` module with shell=True only when necessary, such as for debugging purposes or system administration tasks where it would be inappropriate without; b.
#
# Ensure all user input and output are properly sanitized before passing them through subprocess calls that use this parameter (either by using Python's built-in functions to handle these safely). 3) Consider rewriting your code if possible, avoiding the need for `subprocess` with shell=True.
#
# Remember: It is always best practice when dealing directly or indirectly through a subroutine call that uses this parameter (shell), it should be treated as an unsafe method and handled accordingly to prevent potential security issues in Python applications where user input may not have been sanitized properly before being passed into these functions.
#
# Source(s):
#   1.  B602: subprocess_popen_with_shell_equals_true — Bandit documentation;  (https://bandit.readthedocs.io/en/latest/plugins/b602_subprocess_popen_with_shell_equals_true.html)
#   2.  subprocess — Subprocess management;  (https://docs.python.org/3/library/subprocess.html)
#   3.  bandit.plugins.injection_shell — Bandit documentation;  (https://bandit.readthedocs.io/en/latest/_modules/bandit/plugins/injection_shell.html)
#   4.  Command Injection in Python | Semgrep;  (https://semgrep.dev/docs/cheat-sheets/python-command-injection)
#   5.  B603: subprocess_without_shell_equals_true — Bandit documentation;  (https://bandit.readthedocs.io/en/latest/plugins/b603_subprocess_without_shell_equals_true.html)
#
#
# Prompt Tokens: 331
# Max New Tokens: 360
# ----------------------------------------------------------------------------------------
#
# Question 4: What is a secure hashing algorithm to use instead of md5?
# Cleaned Response: A secure hashing algorithm to use instead of MD5 is SHA-2.
#
# It's a more up-to date and robust alternative that can be used for security purposes, such as password storage or data integrity checks in cryptographic protocols like SSL TLS (HTTPS).
#
# Source(s):
#   1.  What is an insecure hash? | Tutorial & examples | Snyk Learn;  (https://learn.snyk.io/lesson/insecure-hash/)
#   2.  Find Weak Cryptographic Algorithms: Bye Bye MD5 | Testing for Weak Cryptography with Snyk | Snyk;  (https://snyk.io/blog/can-snyk-find-weak-cryptographic-algorithms-bye-bye-md5/)
#   3.  Password Storage - OWASP Cheat Sheet Series;  (https://cheatsheetseries.owasp.org/cheatsheets/Password_Storage_Cheat_Sheet.html)
#   4.  hashlib — Secure hashes and message digests;  (https://docs.python.org/3/library/hashlib.html)
#   5.  WSTG - Latest | OWASP Foundation;  (https://owasp.org/www-project-web-security-testing-guide/latest/4-Web_Application_Security_Testing/09-Testing_for_Weak_Cryptography/04-Testing_for_Weak_Encryption)
#
#
# Prompt Tokens: 63
# Max New Tokens: 360
# ----------------------------------------------------------------------------------------
#
# Question 5: What are common hardcoded secret patterns detected by Dodgy in Python?
# Cleaned Response: Hardcoded secrets are a common security risk in Python applications.
#
# Dodgy, an open-source tool for detecting hardcoding of sensitive information like API keys and passwords within code repositories or files on disk (not just the source), has identified several patterns that developers should avoid: storing plain text versions without encryption; not rotating secrets regularly to prevent long term exposure.
#
# It is important to implement proper security measures such as using secure storage methods, rotation of credentials when necessary for better protection against data breaches and unauthorized access
#
# Source(s):
#   1.  Hardcoded secrets | Tutorial and examples | Snyk Learn;  (https://learn.snyk.io/lesson/hardcoded-secrets/)
#   2.  Want to avoid a data breach? Employ secrets detection - SEO | Snyk;  (https://snyk.io/blog/want-to-avoid-data-breach-employ-secrets-detection/)
#   3.  Avoiding Secret Leaks in Python Projects | ArjanCodes;  (https://arjancodes.com/blog/how-to-prevent-secrets-leakage-in-your-python-projects/)
#   4.  detect-secrets - Python Package Health Analysis | Snyk;  (https://snyk.io/advisor/python/detect-secrets)
#   5.  Semgrep;  (https://semgrep.dev/p/secrets)
#
#
# Prompt Tokens: 113
# Max New Tokens: 360
# ----------------------------------------------------------------------------------------

# %%
# Django Cleanup

# Path to your temp project (adjust if needed)
temp_project_path = os.path.join(os.getcwd(), "temp_project")

# Remove the directory and all contents
if os.path.exists(temp_project_path):
    shutil.rmtree(temp_project_path)
    print(f"Removed: {temp_project_path}")
else:
    print("No temp_project folder found.")
# Out:
# Removed: /home/flaniganp/Documents/my-python-buddy/notebook/temp_project
